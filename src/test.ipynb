# %%
from langchain_tavily import TavilySearch

# %%
search_tool = TavilySearch(max_results=3, name="web_search")

# %%
search_tool.run("What is the capital of France?")
# Out:
# {'query': 'What is the capital of France?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://www.worldatlas.com/articles/what-is-the-capital-of-france.html',
#    'title': 'What is the Capital of France? - World Atlas',
#    'content': 'Paris is the capital city of France. The city has an approximate area of 41 square miles with a population of 2,206,488 people as of 2018. Contrary to popular belief, the name of the city did not come from the Paris in Greek myths. Instead, the name Paris is derived from the city’s initial inhabitants who were part of the Celtic Parisii tribe. Located in the north of Central France, the city is relatively flat with the highest point being 427 feet (which is Montmartre) above sea level while the lowest point is 115 feet above the sea level. With a GDP of approximately $850 billion, Paris is the country’s leader for economic activities. Tourists are attracted to Paris because of the rich history the city has including its monuments and sights. As the capital city of France, the city plays host to the national government of France. ### The 10 Most Densely Populated Countries In The World. ### The 10 Most Populated Countries In The World.',
#    'score': 0.921591,
#    'raw_content': None},
#   {'url': 'https://home.adelphi.edu/~ca19535/page%204.html',
#    'title': 'Paris facts: the capital of France in history',
#    'content': '## Paris facts: Paris, the **capital of France**. Paris is the **capital of France**, the largest country of Europe with 550 000 km2 (65 millions inhabitants). Paris has 2.234 million inhabitants end 2011. ## Paris facts: Paris history. From the Romans to the Vth Republic, Paris has a rich 2000 year history. See details of Paris history. ## Paris facts: Paris, a world city. Paris is a world capital city of shopping and fashion, with Channel, Dior, Vuitton, Yves Saint Laurent among many other top french fashion brands. ## Paris facts: the capital of France in history. Before Paris, the capital of France was Lyon (under the Romans). Paris first became the capital of France in 508 under King Clovis. After centuries with no unique capital of France, Paris retrieved its status of capital of France under King Philippe Auguste, who reigned between 1180 and 1223. Paris remained the capital of France until today, with one four year interruption.',
#    'score': 0.8619225,
#    'raw_content': None},
#   {'url': 'https://study.com/academy/lesson/facts-about-france-location-population-history.html',
#    'title': 'Facts About France | Map, Population & Capital - Study.com',
#    'content': "# Facts About France | Map, Population & Capital. ## The Country of France. France has been a democracy since Napoleon III was overthrown in 1870, except for a brief interlude when it was occupied by Nazi Germany during the Second World War. To unlock this lesson you must be a Study.com Member. ## Where is France? ### Map of France. ## Facts About France. Thanks to France's cultural influence and extensive colonial empire, many other countries also have large French-speaking populations. ### France Population. ### Capital of France. Paris is the capital of France and one of the most well-known cities in the world. #### What are five interesting facts about France? France's capital is Paris. France has a population of 68 million. The language of France (French) is spoken by many more millions of people across the world. #### *Facts About France | Map, Population & Capital* Related Study Materials. * Landmarks in France Lesson for Kids.",
#    'score': 0.83710164,
#    'raw_content': None}],
#  'response_time': 0.0,
#  'request_id': 'a9fc395c-6d6b-4b66-b8de-5b087942c760'}
